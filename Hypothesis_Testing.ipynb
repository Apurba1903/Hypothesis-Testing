# %% [markdown]
# ## Independent 2 Sample T-Test
#
#
# ### Practice problem from Page 9 of Session 2 on Hypothesis Testing

# %%
from scipy.stats import t

# Set the t-value and degrees of freedom
t_value = -1.25
df = 24  # Replace this with your specific degrees of freedom

# Calculate the CDF value
cdf_value = t.cdf(t_value, df)
print(cdf_value)
# Out:
# 0.1116757390828102

# %%
"""

# The Shapiro-Wilk test returns two values: the test statistic (W) and the p-value.

# If the p-value is greater than your chosen significance level (α = 0.05), you can assume the data comes from a normally distributed population.

# If the p-value is less than or equal to the significance level, the normality assumption is not met, and you should consider applying a data transformation or using a non-parametric test like the Mann-Whitney U test.

"""

from scipy.stats import shapiro

# Input the data as lists
desktop_users = [12, 15, 18, 16, 20, 17, 14, 22, 19, 21, 23, 18, 25, 17, 16, 24, 20, 19, 22, 18, 15, 14, 23, 16, 12, 21, 19, 17, 20, 14]
mobile_users = [10, 12, 14, 13, 16, 15, 11, 17, 14, 16, 18, 14, 20, 15, 14, 19, 16, 15, 17, 14, 12, 11, 18, 15, 10, 16, 15, 13, 16, 11]

# Perform the Shapiro-Wilk test for both desktop and mobile users
shapiro_desktop = shapiro(desktop_users)
shapiro_mobile = shapiro(mobile_users)

print("Desktop Users:", shapiro_desktop)
print("\nMobile Users:", shapiro_mobile)
# Out:
# Desktop Users: ShapiroResult(statistic=0.9783115512411942, pvalue=0.7791003299808725)
#
# Mobile Users: ShapiroResult(statistic=0.9714355768676655, pvalue=0.5791606602037616)

# %%
"""

# If the p-value from Levene's test is greater than your chosen significance level (α = 0.05), you can assume equal variances.

#  If the p-value is less than or equal to the significance level, the assumption of equal variances is not met, and you should consider using Welch's t-test instead of the regular independent two-sample t-test.

"""


from scipy.stats import levene

# Input the data as lists
desktop_users = [12, 15, 18, 16, 20, 17, 14, 22, 19, 21, 23, 18, 25, 17, 16, 24, 20, 19, 22, 18, 15, 14, 23, 16, 12, 21, 19, 17, 20, 14]
mobile_users = [10, 12, 14, 13, 16, 15, 11, 17, 14, 16, 18, 14, 20, 15, 14, 19, 16, 15, 17, 14, 12, 11, 18, 15, 10, 16, 15, 13, 16, 11]

# Perform Levene's test
levene_test = levene(desktop_users, mobile_users)
print(levene_test)
# Out:
# LeveneResult(statistic=2.94395488191752, pvalue=0.09153720526741756)

# %%
from scipy.stats import t

# Set the t-value and degrees of freedom
t_value = -5.25
df = 58  # Replace this with your specific degrees of freedom

# Calculate the CDF value
cdf_value = t.cdf(t_value, df)
print(cdf_value*2)
# Out:
# 2.2563697469332243e-06

# %% [markdown]
# H0, Md == Mm
#
# But it is wrong
#
# So we can Reject the Null Hypothesis

# %% [markdown]
# ## Paired 2 Sample T-Test

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

before = np.array([80, 92, 75, 68, 85, 78, 73, 90, 70, 88, 76, 84, 82, 77, 91])
after = np.array([78, 93, 81, 67, 88, 76, 74, 91, 69, 88, 77, 81, 80, 79, 88])

# %% [markdown]
# Ho, Mbefore = Mafter
#
# Ha, Mbefore > Mafter

# %%
difference = after - before

# %%
plt.hist(difference)
plt.title("Histogram of Weight Differences")
plt.xlabel("Weight Difference (KG)")
plt.ylabel("Frequency")
plt.show()

# %%
shapiro_test = stats.shapiro(difference)
print("Shapiro-Wilk Test:", shapiro_test)
# Out:
# Shapiro-Wilk Test: ShapiroResult(statistic=0.9220571486009436, pvalue=0.20704778986900568)

# %%
mean_diff = np.mean(difference)
std_diff = np.std(difference, ddof=1)

# %%
n = len(difference)

t_statistic = mean_diff / (std_diff / np.sqrt(n))

df = n - 1

# %%
t_statistic
# Out:
# 0.10482848367219182

# %%
alpha = 0.05

p_value = stats.t.cdf(t_statistic, df)

# %%
p_value
# Out:
# 0.5410005146857456

# %% [markdown]
# Could not Reject the Null Hypothesis
