# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('Titanic/train.csv').drop(columns=['Survived'])
test = pd.read_csv('Titanic/test.csv')

# %%
final_df = pd.concat([train,test]).sample(1309)

# %%
pop = final_df['Age'].dropna()

# %%
pop.mean()
# Out:
# 29.881137667304014

# %%
sample_age = pop.sample(25).values

# %%
sample_age
# Out:
# array([15., 27., 55., 21., 19., 25., 19., 32., 27., 34., 48., 50., 20.,
#        23., 10., 30., 54., 37., 32., 25., 21., 14., 19., 29.,  8.])

# %% [markdown]
# `# H0 -> The mean age is 35`
#
# `# H1 -> The mean is less than 35`

# %% [markdown]
# `# Check for normality using Shapiro Wilk Test`

# %%
from scipy.stats import shapiro

shapiro_age = shapiro(sample_age)

print(shapiro_age)
# Out:
# ShapiroResult(statistic=0.9244240380793508, pvalue=0.06466923296505422)

# %% [markdown]
# `If p-value < 0.05 then Not Normal`
#
# `Or p-value > 0.05 then Normal`

# %%
pop_mean = 35

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_1samp(sample_age, pop_mean)

print("t-statistic:", t_statistic)
print("p-value:", p_value/2)
# Out:
# t-statistic: -2.8108786970949025
# p-value: 0.004840638179925349

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Reject the null hypothesis.

# %%
pop
# Out:
# 798    30.0
# 352    15.0
# 3      27.0
# 345    16.0
# 24      8.0
#        ...
# 71     21.0
# 212    22.0
# 756    28.0
# 260    36.5
# 270    46.0
# Name: Age, Length: 1046, dtype: float64
