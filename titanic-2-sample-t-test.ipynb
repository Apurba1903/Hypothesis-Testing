# %%
import numpy as np 
import pandas as pd

# %%
train = pd.read_csv('Titanic/train.csv').drop(columns=['Survived'])
test = pd.read_csv('Titanic/test.csv')

# %%
final_df = pd.concat([train,test]).sample(1309)

# %%
pop_male = final_df[final_df['Sex'] == 'male']['Age'].dropna()
pop_female = final_df[final_df['Sex'] == 'female']['Age'].dropna()

# %%
pop_female
# Out:
# 874    28.0
# 865    42.0
# 627    21.0
# 184     4.0
# 18     31.0
#        ...
# 120    12.0
# 119    29.0
# 117     1.0
# 290    26.0
# 474    22.0
# Name: Age, Length: 388, dtype: float64

# %%
sample_male = pop_male.sample(25)
sample_female = pop_female.sample(25)

alpha = 0.05

# %% [markdown]
# `# H0 - Mean age of male and female are similar`
#
# `# H1 - Mean age of male is higher than female`

# %%
pop_male.mean()
# Out:
# 30.58522796352584

# %%
pop_female.mean()
# Out:
# 28.68708762886598

# %%
from scipy.stats import shapiro

# Perform the Shapiro-Wilk test for both desktop and mobile users
shapiro_male = shapiro(sample_male)
shapiro_female = shapiro(sample_female)

print("Desktop users:", shapiro_male)
print("Mobile users:", shapiro_female)
# Out:
# Desktop users: ShapiroResult(statistic=0.9649166634912025, pvalue=0.5207597923847347)
# Mobile users: ShapiroResult(statistic=0.9697955536847491, pvalue=0.639888069191652)

# %%
from scipy.stats import levene

# Perform Levene's test
levene_test = levene(sample_male, sample_female)
print(levene_test)
# Out:
# LeveneResult(statistic=2.193356782910084, pvalue=0.14514185148409756)

# %%
import scipy.stats as stats

t_statistic, p_value = stats.ttest_ind(sample_male, sample_female)

print("t-statistic:", t_statistic)
print("p-value:", p_value/2)
# Out:
# t-statistic: 0.1268265732992354
# p-value: 0.44980373173773114

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")
# Out:
# Fail to reject the null hypothesis.
